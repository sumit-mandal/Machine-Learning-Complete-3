# %% [markdown]
# ## Series

# %%
import pandas as pd

# series 
series = pd.Series(['BMW','Toyota','Honda'])

# %%
series
# Out:
# 0       BMW
# 1    Toyota
# 2     Honda
# dtype: object

# %%
### Series is 1 dimensional

# %%
colours = pd.Series(["Red","Blue","White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %%
## DataFrame = 2-Dimensional
car_data = pd.DataFrame({"Car make":series,"colour":colours})
car_data
# Out:
#   Car make colour
# 0      BMW    Red
# 1   Toyota   Blue
# 2    Honda  White

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/car-sales-extended.csv")

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### Describing the data

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price             int64
# dtype: object

# %%
df.columns ## since columns doesn't have brackets() it is attribute
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = df.columns

# %%
### car_columns is now a list
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# ### LOC and ILOC

# %%
animals = pd.Series(["cat",'dog','bird','snake'],
                   index=[0,3,9,4])

# %%
animals = pd.DataFrame(animals)
animals
# Out:
#        0
# 0    cat
# 3    dog
# 9   bird
# 4  snake

# %%
animals.columns=['jaanwar']

# %%
animals
# Out:
#   jaanwar
# 0     cat
# 3     dog
# 9    bird
# 4   snake

# %%
animals.loc[3]['jaanwar']
# Out:
# 'dog'

# %%
df['Make']
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
df.Make
# Out:
# 0       Honda
# 1         BMW
# 2       Honda
# 3      Toyota
# 4      Nissan
#         ...
# 995    Toyota
# 996    Nissan
# 997    Nissan
# 998     Honda
# 999    Toyota
# Name: Make, Length: 1000, dtype: object

# %%
df[df['Make']=='Toyota'].value_counts()
# Out:
# Make    Colour  Odometer (KM)  Doors  Price
# Toyota  White   248815         4      9785     1
#         Blue    189209         4      7100     1
#                 190406         4      20867    1
#                 191232         4      18355    1
#                 192543         4      13213    1
#                                               ..
#         White   59222          4      32676    1
#                 61623          4      35760    1
#                 62712          4      24342    1
#                 63832          4      6698     1
#         Black   17975          4      17940    1
# Length: 398, dtype: int64

# %%
df['Make'].value_counts()
# Out:
# Toyota    398
# Honda     304
# Nissan    198
# BMW       100
# Name: Make, dtype: int64

# %%
df[df['Odometer (KM)']>100000]
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 1       BMW   Blue         192714      5  19943
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# 6    Toyota   Blue         163453      4   8473
# 8    Nissan  White         130538      4   9374
# ..      ...    ...            ...    ...    ...
# 993  Nissan  Black         162523      4   4696
# 994     BMW   Blue         163322      3  31666
# 996  Nissan  White         155144      3   5716
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [627 rows x 5 columns]

# %% [markdown]
# ### Selecting two columns and viewing them

# %%
pd.crosstab(df["Make"],df["Doors"])
# Out:
# Doors    3    4   5
# Make
# BMW     21    0  79
# Honda    0  304   0
# Nissan  44  154   0
# Toyota   0  398   0

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
import seaborn as sns

# %%
sns.relplot(data=df,y='Price',x='Odometer (KM)',kind='line',hue="Doors")

# %% [markdown]
# ### Groupby

# %%
df.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)     Doors         Price
# Make
# BMW     123540.800000  4.580000  27089.830000
# Honda   124667.671053  4.000000  14514.200658
# Nissan  135480.308081  3.777778  13658.368687
# Toyota  135667.223618  4.000000  15628.160804

# %%
df.groupby(["Make"])

# %% [markdown]
# ## Convert price to integer

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
df1 = pd.read_csv("Data/7.1 car-sales.csv")

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df1['Price'] = df1['Price'].str.replace('[\$\,\.]','').astype(int)

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
df1['Price'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating data

# %%
car_sales_missing = pd.read_csv("DATA/9.2 car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %% [markdown]
# ### Create new columns

# %%
# seats_column = pd.Series([5,5,5,5,5])

# df = df.drop(['Seats'],axis=1)

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors  Price
# 0     Honda  White          35431      4  15323
# 1       BMW   Blue         192714      5  19943
# 2     Honda  White          84714      4  28343
# 3    Toyota  White         154365      4  13434
# 4    Nissan   Blue         181577      3  14043
# ..      ...    ...            ...    ...    ...
# 995  Toyota  Black          35820      4  32042
# 996  Nissan  White         155144      3   5716
# 997  Nissan   Blue          66604      4  31570
# 998   Honda  White         215883      4   4001
# 999  Toyota   Blue         248360      4  12732
#
# [1000 rows x 5 columns]

# %%
seats_column = pd.Series([5,5,5,5,5])

# New column called seats
df1['Seats'] = seats_column

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    NaN
# 6   Honda   Blue          45698      4   750000    NaN
# 7   Honda   Blue          54738      4   700000    NaN
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
df1['Seats'].fillna(5,inplace=True)

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     BMW  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    5.0
# 6   Honda   Blue          45698      4   750000    5.0
# 7   Honda   Blue          54738      4   700000    5.0
# 8  Toyota  White          60000      4   625000    5.0
# 9  Nissan  White          31600      4   970000    5.0

# %%
### Column from python list
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.7,7.6,4.6,8.7,3.0]
df1['fuel per 100KM'] = fuel_economy
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    5.0             9.2
# 2  Toyota   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 4  Nissan  White         213095      4   350000    5.0             8.7
# 5  Toyota  Green          99213      4   450000    5.0             4.7
# 6   Honda   Blue          45698      4   750000    5.0             7.6
# 7   Honda   Blue          54738      4   700000    5.0             4.6
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             3.0

# %%
df1['Total fuel used'] = df1["Odometer (KM)"]/100 * df1['fuel per 100KM']

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    5.0             9.2
# 2  Toyota   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 4  Nissan  White         213095      4   350000    5.0             8.7
# 5  Toyota  Green          99213      4   450000    5.0             4.7
# 6   Honda   Blue          45698      4   750000    5.0             7.6
# 7   Honda   Blue          54738      4   700000    5.0             4.6
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             3.0
#
#    Total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# 7         2517.948
# ...

# %%
df1["Number of wheels"] = 4
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    5.0             9.2
# 2  Toyota   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 4  Nissan  White         213095      4   350000    5.0             8.7
# 5  Toyota  Green          99213      4   450000    5.0             4.7
# 6   Honda   Blue          45698      4   750000    5.0             7.6
# 7   Honda   Blue          54738      4   700000    5.0             4.6
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             3.0
#
#    Total fuel used  Number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# ...

# %%
df1['Passed Road Safety'] = True
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM  \
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 1   Honda    Red          87899      4   500000    5.0             9.2
# 2  Toyota   Blue          32549      3   700000    5.0             5.0
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 4  Nissan  White         213095      4   350000    5.0             8.7
# 5  Toyota  Green          99213      4   450000    5.0             4.7
# 6   Honda   Blue          45698      4   750000    5.0             7.6
# 7   Honda   Blue          54738      4   700000    5.0             4.6
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 9  Nissan  White          31600      4   970000    5.0             3.0
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Make                10 non-null     object
#  1   Colour              10 non-null     object
#  2   Odometer (KM)       10 non-null     int64
#  3   Doors               10 non-null     int64
#  4   Price               10 non-null     int32
#  5   Seats               10 non-null     float64
#  6   fuel per 100KM      10 non-null     float64
#  7   Total fuel used     10 non-null     float64
#  8   Number of wheels    10 non-null     int64
#  9   Passed Road Safety  10 non-null     bool
# dtypes: bool(1), float64(3), int32(1), int64(3), object(2)
# memory usage: 818.0+ bytes

# %% [markdown]
# ### Changing the order

# %%
df1.sample(frac=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM  \
# 3     BMW  Black          11179      5  2200000    5.0             9.6
# 8  Toyota  White          60000      4   625000    5.0             8.7
# 6   Honda   Blue          45698      4   750000    5.0             7.6
# 4  Nissan  White         213095      4   350000    5.0             8.7
# 1   Honda    Red          87899      4   500000    5.0             9.2
# 5  Toyota  Green          99213      4   450000    5.0             4.7
# 2  Toyota   Blue          32549      3   700000    5.0             5.0
# 9  Nissan  White          31600      4   970000    5.0             3.0
# 0  Toyota  White         150043      4   400000    5.0             7.5
# 7   Honda   Blue          54738      4   700000    5.0             4.6
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 3         1073.184                 4                True
# 8         5220.000                 4                True
# ...

# %%
df1_shuffled = df1.sample(frac=0.5)
df1_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  fuel per 100KM  \
# 1   Honda    Red          87899      4  500000    5.0             9.2
# 7   Honda   Blue          54738      4  700000    5.0             4.6
# 0  Toyota  White         150043      4  400000    5.0             7.5
# 6   Honda   Blue          45698      4  750000    5.0             7.6
# 8  Toyota  White          60000      4  625000    5.0             8.7
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 1         8086.708                 4                True
# 7         2517.948                 4                True
# 0        11253.225                 4                True
# 6         3473.048                 4                True
# 8         5220.000                 4                True

# %%
df1_shuffled.reset_index()
# Out:
#    index    Make Colour  Odometer (KM)  Doors   Price  Seats  fuel per 100KM  \
# 0      1   Honda    Red          87899      4  500000    5.0             9.2
# 1      7   Honda   Blue          54738      4  700000    5.0             4.6
# 2      0  Toyota  White         150043      4  400000    5.0             7.5
# 3      6   Honda   Blue          45698      4  750000    5.0             7.6
# 4      8  Toyota  White          60000      4  625000    5.0             8.7
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0         8086.708                 4                True
# 1         2517.948                 4                True
# 2        11253.225                 4                True
# 3         3473.048                 4                True
# 4         5220.000                 4                True

# %%
df1_shuffled.reset_index(drop=True,inplace=True)

# %%
df1_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  fuel per 100KM  \
# 0   Honda    Red          87899      4  500000    5.0             9.2
# 1   Honda   Blue          54738      4  700000    5.0             4.6
# 2  Toyota  White         150043      4  400000    5.0             7.5
# 3   Honda   Blue          45698      4  750000    5.0             7.6
# 4  Toyota  White          60000      4  625000    5.0             8.7
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0         8086.708                 4                True
# 1         2517.948                 4                True
# 2        11253.225                 4                True
# 3         3473.048                 4                True
# 4         5220.000                 4                True

# %%
df1['Odometer (KM)'] = df1["Odometer (KM)"].apply(lambda x:x/1.6094)
df1
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  fuel per 100KM  \
# 0  Toyota  White   93229.153722      4   400000    5.0             7.5
# 1   Honda    Red   54616.005965      4   500000    5.0             9.2
# 2  Toyota   Blue   20224.307195      3   700000    5.0             5.0
# 3     BMW  Black    6946.066857      5  2200000    5.0             9.6
# 4  Nissan  White  132406.486890      4   350000    5.0             8.7
# 5  Toyota  Green   61645.955014      4   450000    5.0             4.7
# 6   Honda   Blue   28394.432708      4   750000    5.0             7.6
# 7   Honda   Blue   34011.432832      4   700000    5.0             4.6
# 8  Toyota  White   37280.974276      4   625000    5.0             8.7
# 9  Nissan  White   19634.646452      4   970000    5.0             3.0
#
#    Total fuel used  Number of wheels  Passed Road Safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
! git add Intro_pandas.ipynb DATA/.
